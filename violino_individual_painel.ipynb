# %% [markdown]
# <a href="https://colab.research.google.com/github/ludmillaconti/data-analytics/blob/main/violino_individual_painel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns


#mpl.rcParams['font.size'] = 12
#mpl.rcParams['legend.fontsize'] = 'large'
#mpl.rcParams['figure.titlesize'] = 'medium'




tabela_dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Gráficos para artigos/guara_17 (1).csv')
tabela_dados = tabela_dados.rename(columns={'hour': 'date'})
tabela_dados = pd.DataFrame(tabela_dados)

#tabela_dados = tabela_dados.drop(['date', 'NO 17', 'NO 18', 'NO 19', 'NO 20', 'NO2 17', 'NO2 18', 'NO2 19', 'NO2 20'], axis=1)
#tabela_dados = tabela_dados.drop(['date', 'NO2 17', 'NO2 18', 'NO2 19', 'NO2 20', axis=1)
#tabela_dados = tabela_dados.drop(['date', 'O3 17', 'O3 18', 'O3 19', 'O3 20', axis=1)
#tabela_dados = tabela_dados.drop('NO 17', axis=1)

tabela_dados = tabela_dados.fillna(tabela_dados.mean())


display(tabela_dados)
# Out:
#       date     NO 17     NO2 17  O3 17  ...  .O3 19     .NO 20    .NO2 20  .O3 20
# 0    01:00  3.489703  13.139588   23.0  ...    32.0   6.528846  16.763285     3.0
# 1    02:00  2.000000  22.000000    8.0  ...    30.0  26.000000  40.000000     2.0
# 2    03:00  1.000000  22.000000   12.0  ...    10.0  15.000000  34.000000     2.0
# 3    04:00  0.000000  16.000000   16.0  ...    12.0  17.000000  30.000000     1.0
# 4    05:00  0.000000   9.000000   31.0  ...     9.0  37.000000  31.000000     1.0
# ..     ...       ...        ...    ...  ...     ...        ...        ...     ...
# 451  20:00  1.000000  10.000000   51.0  ...    22.0   6.528846  16.763285     4.0
# 452  21:00  0.000000   9.000000   45.0  ...    10.0   6.528846  16.763285     3.0
# 453  22:00  1.000000   9.000000   40.0  ...     2.0   6.528846  16.763285     3.0
# 454  23:00  1.000000  11.000000   35.0  ...     2.0   6.528846  16.763285    23.0
# ...

# %%
display(tabela_dados.describe().T)
# Out:
#          count       mean        std  min    25%        50%        75%    max
# NO 17    456.0   3.489703   6.168193  0.0   0.00   1.000000   3.489703   44.0
# NO2 17   456.0  13.139588   8.145178  2.0   7.00  12.000000  16.000000   49.0
# O3 17    456.0  27.570115  21.698362  0.0   8.00  25.000000  41.000000   84.0
# NO 18    456.0   2.038902   3.989640  0.0   0.00   0.000000   2.000000   37.0
# NO2 18   456.0  11.592677   8.829707  1.0   5.00  10.000000  15.000000   58.0
# O3 18    456.0  32.478261  20.632581  2.0  14.00  31.000000  49.250000   94.0
# NO 19    456.0   4.195175   7.613988  0.0   0.00   1.000000   5.000000   56.0
# NO2 19   456.0  15.395881  10.629682  1.0   7.00  13.000000  20.250000   59.0
# O3 19    456.0  34.626728  23.079487  6.0  16.00  30.000000  47.250000  102.0
# NO 20    456.0   2.642691   4.789864  0.0   0.00   1.000000   3.000000   32.0
# NO2 20   456.0  12.928074   9.792660  1.0   6.00  10.000000  15.250000   62.0
# ...

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))


a = sns.violinplot(ax = axes[0,0], data = tabela_dados[['NO 17', 'NO 18', 'NO 19', 'NO 20']])
a.set_title('Guratinguetá - NO')
a.set_ylabel('Gas concentration')
b = sns.violinplot(ax = axes[0,1], data = tabela_dados[['NO2 17', 'NO2 18', 'NO2 19', 'NO2 20']])
b.set_title('Guratinguetá - NO2')
c = sns.violinplot(ax = axes[0,2], data = tabela_dados[['O3 17', 'O3 18', 'O3 19', 'O3 20']])
c.set_title('Guratinguetá - O3')
d = sns.violinplot(ax = axes[1,0], data = tabela_dados[['.NO 17', '.NO 18', '.NO 19', '.NO 20']])
d.set_title('São José dos Campos- NO')
d.set_ylabel('Gas concentration')
e = sns.violinplot(ax = axes[1,1], data = tabela_dados[['.NO2 17', '.NO2 18', '.NO2 19', '.NO2 20']])
e.set_title('São José dos Campos- NO2')
f = sns.violinplot(ax = axes[1,2], data = tabela_dados[['.O3 17', 'O3 18.', '.O3 19', '.O3 20']])
f.set_title('São José dos Campos- O3')

plt.savefig('violino.png')

# %%
#tabela_dados = tabela_dados.groupby('date').mean()
fig = plt.figure()
plt.figure(figsize=(8, 6))

ax = sns.violinplot(data = tabela_dados)
ax.set_title('Guratinguetá - O3')
ax.set_ylabel('Gas Concentrations', weight='bold')
ax.set_xlabel('Chemical Compounds per year ')

#fig.subplots_adjust(bottom=0.15, left=0.2) espaçamentos entre os ticks

plt.tight_layout()

_ = ax.set_xticklabels(tabela_dados.keys())#, rotation=90)
